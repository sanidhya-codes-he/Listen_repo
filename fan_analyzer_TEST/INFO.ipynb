# %% [markdown]
# ## Info Of this Folder

# %% [markdown]
# #### Contains the model built and the python script used to build it, doesnot represent the actual model or pipeline

# %% [markdown]
# ## Fan labels as according to model build
# #### fan_id00 - 0
# #### fan_id02 - 1
# #### fan_id04 - 2
# #### fan_id06 - 3
