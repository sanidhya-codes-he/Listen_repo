# %% [markdown]
# ## This File only contains information for the respective folder
# #### Folder files display only the working/building of the model
# #### The main Model is 'base_comp_model.joblib'
# #### Model used to identify what type of COMPONENT it is - valve, fan, pump, slider

# %% [markdown]
# The file comp_identifier_data_prep.py is used to bring all data into a single csv file to train our model - allComp_data.csv

# %% [markdown]
# the file comp_identifier_model_build.py is the desktop build version of the model which is redundant in the model build
# instead, the model was build on CompDataModel.ipynb

# %% [markdown]
# ## The components are refered with integers
# #### 0 - valve
# #### 1 - slider
# #### 2 - pump
# #### 3 - fan
