# %% [markdown]
# ## The components are refered with integers - as according to base_comp_model.joblib output
# #### 0 - valve
# #### 1 - slider
# #### 2 - pump
# #### 3 - fan

# %% [markdown]
# ## The fan types are referred with integers - as according to fan_model.joblib output
# #### fan_id00 - 0
# #### fan_id02 - 1
# #### fan_id04 - 2
# #### fan_id06 - 3

# %% [markdown]
# ## The slider types are referred with integers - as according to slider_model.joblib output
# #### slider_id00 - 0
# #### slider_id02 - 1
# #### slider_id04 - 2
# #### slider_id06 - 3

# %% [markdown]
# ## The pump types are referred with integers - as according to pump_model.joblib output
# #### pump_id00 - 0
# #### pump_id02 - 1
# #### pump_id04 - 2
# #### pump_id06 - 3
